# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\users\amal ashok\anaconda3\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Pillow in c:\users\amal ashok\anaconda3\lib\site-packages (from face_recognition) (8.2.0)
# Requirement already satisfied: Click>=6.0 in c:\users\amal ashok\anaconda3\lib\site-packages (from face_recognition) (7.1.2)
# Collecting dlib>=19.7
#   Using cached dlib-19.24.0.tar.gz (3.2 MB)
# Requirement already satisfied: numpy in c:\users\amal ashok\anaconda3\lib\site-packages (from face_recognition) (1.20.1)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: dlib, face-recognition
#     Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\AMAL ASHOK\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\setup.py'"'"'; __file__='"'"'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-wheel-9al5xyq6'
#        cwd: C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\
#   Complete output (58 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   Building extension for Python 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\build\lib.win-amd64-3.8 -DPYTHON_EXECUTABLE=C:\Users\AMAL ASHOK\anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\build\lib.win-amd64-3.8 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:5 (message):
#
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#     You must use Visual Studio to build a python extension on windows.  If you
#     are getting this error it means you have not installed Visual C++.  Note
#     that there are many flavors of Visual Studio, like Visual Studio for C#
#     development.  You need to install Visual Studio for C++.
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#   -- Configuring incomplete, errors occurred!
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\setup.py", line 222, in <module>
#       setup(
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\site-packages\setuptools\__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\setup.py", line 134, in run
#       self.build_extension(ext)
#     File "C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\setup.py", line 171, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "C:\Users\AMAL ASHOK\anaconda3\lib\subprocess.py", line 364, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\build\\lib.win-amd64-3.8', '-DPYTHON_EXECUTABLE=C:\\Users\\AMAL ASHOK\\anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\build\\lib.win-amd64-3.8', '-A', 'x64']' returned non-zero exit status 1.
#   ----------------------------------------
#   ERROR: Failed building wheel for dlib
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\AMAL ASHOK\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\setup.py'"'"'; __file__='"'"'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-record-v4u5fmlu\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\AMAL ASHOK\anaconda3\Include\dlib'
#          cwd: C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\
#     Complete output (60 lines):
#     running install
#     running build
#     running build_py
#     package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#     Building extension for Python 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
#     Invoking CMake setup: 'cmake C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\build\lib.win-amd64-3.8 -DPYTHON_EXECUTABLE=C:\Users\AMAL ASHOK\anaconda3\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\build\lib.win-amd64-3.8 -A x64'
#     -- Building for: NMake Makefiles
#     CMake Error at CMakeLists.txt:5 (message):
#
#
#
#       !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#       You must use Visual Studio to build a python extension on windows.  If you
#       are getting this error it means you have not installed Visual C++.  Note
#       that there are many flavors of Visual Studio, like Visual Studio for C#
#       development.  You need to install Visual Studio for C++.
#
#
#       !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#     -- Configuring incomplete, errors occurred!
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\setup.py", line 222, in <module>
#         setup(
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\site-packages\setuptools\__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\site-packages\setuptools\command\install.py", line 61, in run
#         return orig.install.run(self)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\setup.py", line 134, in run
#         self.build_extension(ext)
#       File "C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-install-ulys8g1_\dlib_33c09d8afad4400398b4cd50de20ef3e\setup.py", line 171, in build_extension
#         subprocess.check_call(cmake_setup, cwd=build_folder)
#       File "C:\Users\AMAL ASHOK\anaconda3\lib\subprocess.py", line 364, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\build\\lib.win-amd64-3.8', '-DPYTHON_EXECUTABLE=C:\\Users\\AMAL ASHOK\\anaconda3\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\build\\lib.win-amd64-3.8', '-A', 'x64']' returned non-zero exit status 1.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\AMAL ASHOK\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\setup.py'"'"'; __file__='"'"'C:\\Users\\AMAL ASHOK\\AppData\\Local\\Temp\\pip-install-ulys8g1_\\dlib_33c09d8afad4400398b4cd50de20ef3e\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\AMAL ASHOK\AppData\Local\Temp\pip-record-v4u5fmlu\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\AMAL ASHOK\anaconda3\Include\dlib' Check the logs for full command output.

# %%
import cv2
import face_recognition

img = cv2.imread("Messi1.webp")
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = face_recognition.face_encodings(rgb_img)[0]

img2 = cv2.imread("images/Messi.webp")
rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = face_recognition.face_encodings(rgb_img2)[0]

result = face_recognition.compare_faces([img_encoding], img_encoding2)
print("Result: ", result)

cv2.imshow("Img", img)
cv2.imshow("Img 2", img2)
cv2.waitKey(0)
